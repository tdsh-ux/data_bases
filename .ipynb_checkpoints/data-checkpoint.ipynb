# %%
import pandas as pd 
import pymysql 
import csv 
import numpy as np 
from itertools import combinations 

import os 
import networkx as nx 
from getpass import getpass 

import dash
import dash_html_components as html
import dash_cytoscape as cyto 
import matplotlib.pyplot as plt 

import json 
import re

# %%
# Changes here! mantenha as funções do pymysql :) 
user = "user" 
password = getpass()
# Out:
# ········

# %%
CONN = pymysql.connect(host = "localhost", 
              user = user, 
              password = password, 
              db = "db_menu")

# %%
def loadData(table): # get data from mysql database. 

    try: 
        CONN = pymysql.connect(host = "localhost", 
                      user = user, 
                      password = password, 
                      db = "db_menu") 
        query = "SELECT * FROM {}".format(table) 

        df = pd.read_sql(query, conn) 

        return df 
            
            
    except: 
        conn.close()

# %%
dish = loadData("dish") 
dish.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-aafe32016b92> in <module>
# ----> 1 dish = loadData("dish")
#       2 dish.head()
#
# NameError: name 'loadData' is not defined

# %%
menu_item= loadData("menu_item") 
menu_item.head()
# Out:
#    id  menu_page_id  dish_id  price
# 0   1          1389       21   0.25
# 1   2          1389       21   0.25
# 2   3           130       50    NaN
# 3   4         13915       50    NaN
# 4   5          5946      286    NaN

# %%
menu = loadData("menu") 
menu.head()
# Out:
#       id name  event_date  event_id  sponsor_id  currency_id  venue_id
# 0  12463       1900-04-15         1           1            1         1
# 1  12465       1900-04-16         2           2            1         1
# 2  12466       1900-04-16         3           2            1         1
# 3  12470       1900-04-17         2           2            1         1
# 4  12475       1900-04-18         4           3            2         1

# %%
menu_page = loadData("menu_page") 
menu_page.head()
# Out:
#     id  page_number  full_height  full_width  menu_id
# 0  130            1         3049        2004    12463
# 1  134            1         3411        2291    12465
# 2  136            1         3365        2305    12466
# 3  146            1         3427        2282    12470
# 4  168            1         3929        2494    12475

# %% [markdown]
# # Cálculos
#
# Doravante, serão feitos os cálculos para os nós, representados pelos pratos, e as arestas, indicativas da coexistência de refeições em um menu, dos grafos. Para isso, calcularemos, para cada par de pratos, em quantos menus eles aparecem juntos.

# %% [markdown]
# Inicialmente, realizamos as necessárias junções nos conjuntos de dados para obter uma tabela razoável para construir um grafo.

# %%
dish_page = pd.merge(dish, menu_item, left_on = "id", right_on = "dish_id")
#dish_page.head() 
menu_item.head()
# Out:
#    id  menu_page_id  dish_id  price
# 0   1          1389       21   0.25
# 1   2          1389       21   0.25
# 2   3           130       50    NaN
# 3   4         13915       50    NaN
# 4   5          5946      286    NaN

# %%
dish_page_menu = pd.merge(dish_page, menu_page, left_on = "menu_page_id", right_on = "id")
dish_page_menu = dish_page_menu[["name", "dish_id", "menu_page_id", "menu_id"]] 
dish_page_menu.head()
# Out:
#               name  dish_id  menu_page_id  menu_id
# 0  English walnuts       21          1389    12882
# 1  English walnuts       21          1389    12882
# 2  English walnuts       21          3531    13619
# 3    Omelet, plain     2001          3531    13619
# 4  English walnuts       21          4128    13810

# %%
dish_menu = pd.merge(dish_page_menu, menu, left_on = "menu_id", right_on = "id") 
dish_menu = dish_menu[["name_x", "dish_id", "menu_id", "event_date", "event_id", "sponsor_id"]] 
df = dish_menu.rename(columns = {"name_x": "name"}) 
df.head()
# Out:
#               name  dish_id  menu_id  event_date  event_id  sponsor_id
# 0  English walnuts       21    12882  1900-04-09        22          56
# 1  English walnuts       21    12882  1900-04-09        22          56
# 2  English walnuts       21    13619  1901-04-26        22         159
# 3    Omelet, plain     2001    13619  1901-04-26        22         159
# 4  Old Jamaica Rum     1353    13619  1901-04-26        22         159

# %%
# execute a célula seguinte, que contém os scripts sql! 
dish_names = df.name.unique() 

nodes = [] 
count = 0 
for combination in combinations(dish_names, 2): 
    print(count, end = "\r") 
    df_l = df[df["name"] == combination[0]] 
    df_r = df[df["name"] == combination[1]] 
    
    df_lr = pd.merge(df_l, df_r, on = "menu_id") 
    
    x = len(df_lr) 
    
    count = count + 1 
    nodes.append({
        "dish_l": combination[0], 
        "dish_r": combination[1], 
        "count": x 
    })

# %% [markdown]
# Alternativamente, podemos fazer consultas em SQL.

# %%
conn = pymysql.connect(host = "localhost", 
              user = user, 
              password = password, 
              db = "db_menu") 
cur = conn.cursor()

# %%
''' 
change log (2/11) 
- Os nomes dos pratos estão, agora, em lowercase. 
- Eggs with bacons e bacons with eggs são alimentos de semelhança gritante; no entanto, vou mantê-los. 
- adicionei a conexão como argumento da função. 
'''
def get_df(year = None, conn): 
    query_a = """ 
    SELECT dm.dish_id, dm.name, dm.menu_id, menu.event_date, menu.venue_id,   
           dm.menu_page_id FROM menu 
        JOIN (SELECT dish_id, name, menu_page_id, id, menu_id FROM menu_page 
                JOIN (SELECT dish_id, name, menu_page_id FROM dish
                        JOIN menu_item 
                        ON dish.id = menu_item.dish_id) as ds
                ON menu_page.id = ds.menu_page_id) as dm
        ON menu.id = dm.menu_id""" 

    query_b = """SELECT x.dish_id AS dish_id_x, y.dish_id AS dish_id_y, 
                 LOWER(x.name) AS name_x, LOWER(y.name) AS name_y, x.event_date, 
                 x.venue_id, x.menu_page_id, 
                 x.menu_id AS menu_id_x, y.menu_id AS menu_id_y 
                 FROM ({query}) AS x 
                 INNER JOIN ({query}) AS y 
                 ON x.menu_id = y.menu_id 
                 AND x.dish_id < y.dish_id""".format(query = query_a) 

    # filter year 

    if year is not None: 
        query_year = """SELECT * FROM ({query}) as a
                         WHERE YEAR(a.event_date) = {year}""".format(query = query_b, 
                                                                    year = year) 
    else: 
        query_year = query_b 

    query_c = """SELECT a.name_x, a.name_y, COUNT(a.name_x) as count  
                    FROM ({query}) as a 
                    GROUP BY a.name_x, a.name_y 
                    ORDER BY count DESC""".format(query = query_year) 
    df = pd.read_sql(query_c, conn) 
    return df

# %%
df["year"] = list(map(lambda x: int(x[:4]) if x is not None else x, df["event_date"].tolist()))  
years = df.year.unique()

# %%
def save_file(table, name = "table"): 
    try: 
        os.mkdir("./data_csv") 
    except: 
        directory = "./data_csv/" 
    
    csv = table.to_csv(index = False, enconding = "utf-8")  
    
    with open(directory + name + ".csv", "w") as file: 
        file.write(csv)

# %%
save_file(get_df(conn))

# %%
try: 
    for year in years: 
        nodes_year = get_df(year, conn) 
        save_file(nodes_year, name = "nodes_year_" + str(year))     
except Exception as e: 
    print("nan")
# Out:
# nan

# %% [markdown]
# # NetworkX

# %% [markdown]
# Para o que falta, vamos utilizar o Dash Cytoscape para construir a visualização.

# %%
df = get_df() 
np.random.seed(11) 
names_dish = df.name_x.unique() 
print(names_dish)
sample = np.random.choice(len(names_dish), 125) 
names = names_dish[sample]
# Out:
# ['Scrambled Eggs' 'Apple tartlets' 'Prunelle Brandy' 'Cracked Wheat'
#  'Congress Water' 'Salt mackerel' 'Hamburg Chicken' 'Bromo Seltzer'
#  'Cold Consomme' 'Roast Chicken' 'Stuffed Tomato' 'Buttered Toast'
#  'Omelet, plain' 'Blackberry Pie' 'Gin, Plymouth' 'Deviled Crabs'
#  'Potage Lamballe' 'Half Cantaloupe' 'Stewed Rhubarb' 'Salad, Chicken'
#  'SCOTCH WHISKEY' 'Milk Crackers' 'Schweizer Käse' 'Jus de tomate'
#  'Fortune Cakes' 'Salted Pecans' 'Florida Orange' 'Small beefsteak'
#  'Codfish Balls' 'English walnuts' 'Fried Haddock' 'Chicken Halibut'
#  'Consommé Chaud' 'Stuffed Olives' 'Italian Salad' 'Maryland Club'
#  'Figs, in Syrup' 'Old Jamaica Rum' 'Prunes, stewed' 'peach ice cream'
#  'Early June Peas' 'Cream of wheat' 'ALMOND CHICKEN' 'Hennessy 3 Star'
#  'The de Ceylan' 'Coffee Parfait' 'Sea Tag oysters' 'Tomato Sandwich'
#  'Broiled Salmon' 'Chicken, half' 'Corn on the cob' 'Stuffed Prunes'
#  'Egg, Duvivier' 'Bamboo Cocktail' 'English Stilton' 'French Crullers'
#  'Chablis, white' 'Virginia bacon' 'Panachee Salad' 'Curacoa, orange'
#  'UNSALTED BUTTER' 'French Mustard' 'Russ Sardines' 'Crab Cocktail'
#  'Omelet, Cheese' 'Biscuit, Pilot' 'Sea Bass, Vatel' 'Bacon with Eggs'
#  'Beef tea, cup' 'Sauternes 1874' 'Curacao jelly' 'Appetit salad'
#  'Egg plant fried' "Lemp's St Louis" 'Cafe Espresso' 'Buck Gwoo Gong'
#  'New Corn on Cob' 'Apricot Compote' 'Fresh Limeade' 'Orange Pekoë'
#  'Pear ice cream' 'Petite-Suisses' 'Spring Chicken' 'French pastry 1'
#  'Chocolate (cup)' 'Chateau Lafitte' 'French Pickles' 'Comtesse Salade'
#  'Clam pan roast' 'Eggs with bacon' 'Creme caramel' 'Creamed spinach'
#  'Puree, Mongole' 'Chocolate Cuts' 'Calisaya Bark' 'Gefullte Oliven'
#  'French potatoes' 'Salad-Beetroot' 'Tarte de Peche' 'Burgundy Nuits'
#  'Schreider, Dry' 'Pommard, 1889' 'Raspberry Jelly' 'Potatoes Fried'
#  'Nuits Burgundy' 'lobster stuffed' 'Egg Nogg glass' "à l'indienne"
#  'Onions boiled' 'Delice Ecossais' 'Filet of Beef' 'Boneless Bacon'
#  'Vichy (Syphon)' 'Potatoes- Fried' 'Merlans Bercy' 'Iced tea, glass'
#  'Potatoes, Baked' 'Anheuser Busch' 'NARBONNE HONEY' 'Blue Bill Duck'
#  'Boiled haddock' 'Preserves, 20' 'Pieds de Porc' 'Roast on toast'
#  'Hathorn Waters' 'Sliced Tomatoe' 'Passion Fruit' 'Club Saucisses'
#  'Assmannshaeuser' 'Salad, Italian' 'Broma Per Pot' 'Woodford Club'
#  'Lager, Pilsener' 'Vienna Zwieback' 'Consomme (cold)' 'Kentucky Toddy'
#  'St Croix Flip' 'Parsnip Cakes' 'EGG, Baltimore' 'Aspic, Charvin'
#  'Pommes Chateau' 'beef, per cut' 'broiled poussin' 'Pintade (demie)'
#  'Briarcliff Milk' 'Honey Ice Cream' 'Spring Turkey' 'cheddar cheese'
#  'Kieler sprotten' 'Tomate Potage' 'punch romaine' 'Sirloin (for 2)'
#  'Orange sherbet' 'Stuffed Chicken' 'Canard grille' 'Puree Bretonne'
#  'Iced Cucumbers' 'Bouillon froid' 'GATEAU DOMINO' 'Gateau au Rhum'
#  'TOASTED MUFFINS' 'Oatmeal, plain' 'Broil Halibut' 'New Strg Beans'
#  'Slic Tomatoes' 'Cider per quart' 'Imperial Spring' 'Wesphalian Ham'
#  'Pommard, 1893' 'Eggs Fried, two' "Chambertin, '92" 'Isabella salad'
#  'Tomato Chutney' 'Highland Punch' 'Grenoble Nuts' 'Old Roxbury Rye'
#  'Boonekamp, A E' 'Kidneys broiled' 'fried potatoes' 'Puree of peas'
#  'Frascati cake' 'Raspail-Combier' 'Sloe Gin glass' 'Preserved Corn'
#  'Volail le Reine' 'Sherry Golden' 'Chateau Margauz' 'Claret, punch'
#  'Lamb Chops, 2' 'Blackberry tart' 'Cream, goblet' 'Broadway soda'
#  'Roast beef cold' 'Raisins or figs' 'Pilsener Beer' 'Pol Roger, Dry'
#  'G V Ch Giscours' 'Pol Roger  1945' 'Consumme nature' 'Fruit de Saison'
#  'Ovomaltine warm' 'Campari, soda' 'Porter (Tuborg)' 'Maarum Vand Fl'
#  'Rotlack (rott)' 'ENSALADA CHEF' 'Dopff Riesling' 'Selleriesalat'
#  'Coconut Pudding' 'Mx Green Salad' 'Vermouth, Rot' 'Chocolate Sauce'
#  'May Wine Glass' 'Hummer vom Rost' 'Eggs Bohemienne' 'Crawfish tails'
#  'Hunerpastetli' '2 Spiegeleier' 'Calvados 1945' 'Meursault 1962'
#  'Padre Sec 1933' 'Heidsieck 1928' 'Sloe Gin Collin' 'claret cobbler'
#  'Shrimp Newburgh' 'Seafood Gumbo' 'Salad Lorenzo' 'Perch meuniere'
#  'Martell  VSOP' 'Piments Farcis' 'Gemischtersalat' 'Steamed Shrimp'
#  'Orangen Juice' 'St Magdalener' 'Portion Salat' 'Gourmet Dinners'
#  'Canape Greville' 'Chocolate Torte' 'Sliced Poularde' 'Drambuie (2cl)'
#  'SHARK FIN SOUP' 'Utica Club Beer' 'Palm Egg Roll' 'BROILED SCROD'
#  'Hot Fresh Ham' 'Bohemia (Ale)' 'Grouse Pie 16/6' 'Œufs, Rejane'
#  'Kirschenkuchen' 'Treasure Rolls' 'Sirloin-Steak' 'Pomodoro Succhi'
#  'Patate Passate' 'Cavolo bianco' 'Robiola cheese' 'Caribbean Punch'
#  'Panama Daiquiri' 'Young Carrots' 'Saint Emilion' 'Perugina Nougat'
#  'Shrimp on Ice' 'Kannchen Mokka' '1/2 Dozen Clams' 'J Walker (Red)'
#  'Escarole Saute' 'Poulet Mascotte' 'Carstairs Rye' 'Doctor cocktail'
#  'Stuffed Apple' 'Sparkl Burgundy' 'Speck Kartoffel' 'Baked Oysters '
#  'Apple Blossom' 'Spanish Brandy' 'Graves (B & G)' 'Bouquetiere pp'
#  'Lago Di Caldaro' 'CH St-AMAN 1923' 'Madère vieux' 'Whiskey et Gin'
#  "Guinnes's stout" 'stewed tomato' 'Fried Kreplach' 'CARIOCA ZOMBIE'
#  'Belgian Endive' 'Scarole salad' 'Gournay Cheese' 'Piselli freschi'
#  'Almond Cakes ' 'Tysiqc wysp Sos' 'Brandy Crusta' 'Allazu-kimelis'
#  'Curacao, Bols' "Allsop's Beer" 'Hothouse Tomato' 'Shirred Eggs '
#  'dull Prydeinig' 'Potatoe Lorette' 'Stewed Squash' 'Endive with egg'
#  "Thon a l'huille" 'Cazanove, 1906' 'Meringue glacee' 'Port du Saint'
#  'Pommard, 1909' 'Banana Fritters' 'mutton chops ' 'Pudding, Rizzio'
#  'Casaba Melons' 'French pastry' 'Cup clam broth' 'Phila Ice Cream'
#  'Split Pea soup' 'Seatag oysters' 'Soft clam stew' 'Cold duckling'
#  'casawba melon' 'Sponge pudding' 'Fried bluefish' 'Zaza cocktail'
#  'Chicken Wo Main' 'Sauternes, 1905' 'Toast, dipped' 'Boiled mackerel'
#  'Coffee w Cake' 'Paprika Chicken' 'Bombay chutney' 'Eggs Scrambled'
#  'Peach Tapioca' 'Clysmic, split' 'Rock Perfectos' 'Imperial Water'
#  'Salad, Pontin' 'Blue Point Stew' 'Peach Charlotte' 'smoked sardines'
#  'Russian Allasch' 'Salad de Saison' 'Liptauer Cheese' 'Black and white'
#  'pineapple pie' 'Crème vanille' 'Château lafite' 'Filet à lœuf']

# %%
df = df[df["name_x"].isin(names)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 408 entries, 1 to 1754
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name_x  408 non-null    object
#  1   name_y  408 non-null    object
#  2   count   408 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 12.8+ KB

# %%
df.name_x.value_counts()
# Out:
# Stuffed Tomato    45
# Salad, Chicken    34
# Broiled Salmon    29
# Italian Salad     26
# Stewed Rhubarb    22
#                   ..
# Claret, punch      1
# Schreider, Dry     1
# Rock Perfectos     1
# Orange Pekoë       1
# Kirschenkuchen     1
# Name: name_x, Length: 101, dtype: int64

# %%
G = nx.Graph()

# %% [markdown]
# ## Add nodes

# %%
for name in names: 
    G.add_node(name, 
              color = "lightblue")

# %%
for index in range(len(df.index)): 
    G.add_edge(
        df["name_x"].tolist()[index], 
        df["name_y"].tolist()[index], 
        frequency = df["count"].tolist()[index] 
    )

# %%
pos = nx.spring_layout(G, scale=.5)
fig, ax = plt.subplots(figsize=(25,25))
ax.set_title("Food Graph")
nx.draw_networkx(G, pos = pos, node_size = 35, font_size = 5)

# %%
with open('food.json', 'w') as f:
    f.write(json.dumps(nx.cytoscape_data(G)))
